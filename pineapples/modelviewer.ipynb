# %%
cd ~/git/OptimallyAccurate2D
# Out:
# /Volumes/Macintosh HD 2/git/OptimallyAccurate2D

# %%
cd Marmousi/
# Out:
# /Volumes/Macintosh HD 2/git/OptimallyAccurate2D/Marmousi

# %%
import numpy as np
from array import array
import matplotlib
import matplotlib.pyplot as plt



nx=300
nz=100
dx=0.025
dz=0.025

def scale_xaxis(number):
    return(number*dx)
def scale_zaxis(number):
    return(number*dz)
def my_xform(x,pos):
    return '%d'%scale_xaxis(x)
def my_zform(z,pos):
    return '%d'%scale_zaxis(z)

data=np.fromfile('marmousi_vp',dtype=np.float32)

vpmodel=np.reshape(data,(nz,nx))

data=np.fromfile('marmousi_vs',dtype=np.float32)

vsmodel=np.reshape(data,(nz,nx))

# %%
ax=plt.gca()
ax.set_ylabel("Depth [km]")
ax.set_xlabel("Horizontal [km]")
#plt.yticks(np.arange(0,-nz*dz,-0.5))
#plt.xticks(np.arange(0,nx*dx,1.0))
plt.imshow(model,aspect='auto')
ax.autoscale(False)
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(int(50)))
ax.xaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(my_xform))
ax.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(int(50)))
ax.yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(my_zform))
#plt.colorbar()

# %%
plt.imshow(vsmodel)
plt.colorbar()
